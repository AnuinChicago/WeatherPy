# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\aguha\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\aguha\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from time import ctime as convert

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# set up lists to hold reponse info
cityname=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat = []
lng=[]
max_temp = []
windspeed=[]

#setup counter
count=1

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        cityname.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(convert(int(response['dt'])))
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        windspeed.append(response['wind']['speed'])
        print(f"Processing Record for city number {count}, {city}.")
        count= count +1
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Processing Record for city number 1, mataura.
# ------------
# Processing Record for city number 2, georgetown.
# ------------
# Processing Record for city number 3, tuatapere.
# ------------
# Processing Record for city number 4, grindavik.
# ------------
# Processing Record for city number 5, sibolga.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 6, punta arenas.
# ------------
# Processing Record for city number 7, aklavik.
# ------------
# Processing Record for city number 8, kaitangata.
# ------------
# Processing Record for city number 9, christchurch.
# ------------
# Processing Record for city number 10, rikitea.
# ------------
# Processing Record for city number 11, avarua.
# ------------
# Processing Record for city number 12, ushuaia.
# ------------
# Processing Record for city number 13, guilin.
# ------------
# Processing Record for city number 14, jacareacanga.
# ------------
# Processing Record for city number 15, mercedes.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 16, mangrol.
# ------------
# Processing Record for city number 17, bilma.
# ------------
# Processing Record for city number 18, hobart.
# ------------
# Processing Record for city number 19, longyearbyen.
# ------------
# Processing Record for city number 20, husavik.
# ------------
# Processing Record for city number 21, seymchan.
# ------------
# Processing Record for city number 22, uyemskiy.
# ------------
# Processing Record for city number 23, tiksi.
# ------------
# Processing Record for city number 24, tuktoyaktuk.
# ------------
# Processing Record for city number 25, vaini.
# ------------
# Processing Record for city number 26, ayan.
# ------------
# Processing Record for city number 27, lagoa.
# ------------
# Processing Record for city number 28, mizdah.
# ------------
# Processing Record for city number 29, buraydah.
# ------------
# Processing Record for city number 30, arlit.
# ------------
# Processing Record for city number 31, albany.
# ------------
# Processing Record for city number 32, baykit.
# ------------
# Processing Record for city number 33, rio gallegos.
# ------------
# Processing Record for city number 34, mahasamund.
# ------------
# Processing Record for city number 35, cayenne.
# ------------
# Processing Record for city number 36, bandarbeyla.
# ------------
# Processing Record for city number 37, lebu.
# ------------
# Processing Record for city number 38, katsuura.
# ------------
# Processing Record for city number 39, sao filipe.
# ------------
# Processing Record for city number 40, khatanga.
# ------------
# Processing Record for city number 41, chokurdakh.
# ------------
# Processing Record for city number 42, cape town.
# ------------
# Processing Record for city number 43, alofi.
# ------------
# Processing Record for city number 44, gympie.
# ------------
# Processing Record for city number 45, stornoway.
# ------------
# Processing Record for city number 46, treinta y tres.
# ------------
# Processing Record for city number 47, baglan.
# ------------
# Processing Record for city number 48, purpe.
# ------------
# Processing Record for city number 49, pevek.
# ------------
# Processing Record for city number 50, mar del plata.
# ------------
# Processing Record for city number 51, vao.
# ------------
# Processing Record for city number 52, kigoma.
# ------------
# Processing Record for city number 53, rummu.
# ------------
# Processing Record for city number 54, te anau.
# ------------
# Processing Record for city number 55, quepos.
# ------------
# Processing Record for city number 56, leningradskiy.
# ------------
# Processing Record for city number 57, patan.
# ------------
# Processing Record for city number 58, san cristobal.
# ------------
# Processing Record for city number 59, geraldton.
# ------------
# Processing Record for city number 60, pisco.
# ------------
# Processing Record for city number 61, bluff.
# ------------
# Processing Record for city number 62, ibra.
# ------------
# Processing Record for city number 63, flinders.
# ------------
# Processing Record for city number 64, iwanai.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 65, hithadhoo.
# ------------
# Processing Record for city number 66, narsaq.
# ------------
# Processing Record for city number 67, tessalit.
# ------------
# Processing Record for city number 68, nikolskoye.
# ------------
# Processing Record for city number 69, meulaboh.
# ------------
# Processing Record for city number 70, pangnirtung.
# ------------
# Processing Record for city number 71, santa isabel do rio negro.
# ------------
# Processing Record for city number 72, guanica.
# ------------
# Processing Record for city number 73, kolondieba.
# ------------
# Processing Record for city number 74, victoria.
# ------------
# Processing Record for city number 75, san patricio.
# ------------
# Processing Record for city number 76, chuy.
# ------------
# Processing Record for city number 77, langsa.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 78, kapaa.
# ------------
# Processing Record for city number 79, dikson.
# ------------
# Processing Record for city number 80, portland.
# ------------
# Processing Record for city number 81, upernavik.
# ------------
# Processing Record for city number 82, ulladulla.
# ------------
# Processing Record for city number 83, cockburn town.
# ------------
# Processing Record for city number 84, kamenka.
# ------------
# Processing Record for city number 85, shingu.
# ------------
# Processing Record for city number 86, bredasdorp.
# ------------
# Processing Record for city number 87, port keats.
# ------------
# Processing Record for city number 88, jiwani.
# ------------
# Processing Record for city number 89, piacabucu.
# ------------
# Processing Record for city number 90, turan.
# ------------
# Processing Record for city number 91, puerto ayora.
# ------------
# Processing Record for city number 92, lang suan.
# ------------
# Processing Record for city number 93, roros.
# ------------
# Processing Record for city number 94, mon.
# ------------
# Processing Record for city number 95, sorland.
# ------------
# Processing Record for city number 96, formosa.
# ------------
# Processing Record for city number 97, ha tinh.
# ------------
# Processing Record for city number 98, benicarlo.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 99, east london.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 100, yellowknife.
# ------------
# Processing Record for city number 101, sumbawanga.
# ------------
# Processing Record for city number 102, bambous virieux.
# ------------
# Processing Record for city number 103, namibe.
# ------------
# Processing Record for city number 104, busselton.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 105, sakakah.
# ------------
# Processing Record for city number 106, coahuayana.
# ------------
# Processing Record for city number 107, sosnovka.
# ------------
# Processing Record for city number 108, jaisinghnagar.
# ------------
# Processing Record for city number 109, phuket.
# ------------
# Processing Record for city number 110, hermanus.
# ------------
# Processing Record for city number 111, saint george.
# ------------
# Processing Record for city number 112, zyryanka.
# ------------
# Processing Record for city number 113, laramie.
# ------------
# Processing Record for city number 114, chama.
# ------------
# Processing Record for city number 115, tasiilaq.
# ------------
# Processing Record for city number 116, gat.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 117, acapulco.
# ------------
# Processing Record for city number 118, avera.
# ------------
# Processing Record for city number 119, waingapu.
# ------------
# Processing Record for city number 120, hammerfest.
# ------------
# Processing Record for city number 121, berlevag.
# ------------
# Processing Record for city number 122, kismayo.
# ------------
# Processing Record for city number 123, port alfred.
# ------------
# Processing Record for city number 124, dandong.
# ------------
# Processing Record for city number 125, broken hill.
# ------------
# Processing Record for city number 126, vestmannaeyjar.
# ------------
# Processing Record for city number 127, hilo.
# ------------
# Processing Record for city number 128, ereymentau.
# ------------
# Processing Record for city number 129, sabha.
# ------------
# Processing Record for city number 130, praya.
# ------------
# Processing Record for city number 131, esil.
# ------------
# Processing Record for city number 132, kodiak.
# ------------
# Processing Record for city number 133, marsa matruh.
# ------------
# Processing Record for city number 134, jamestown.
# ------------
# Processing Record for city number 135, morondava.
# ------------
# Processing Record for city number 136, maple creek.
# ------------
# Processing Record for city number 137, rawson.
# ------------
# Processing Record for city number 138, tiarei.
# ------------
# Processing Record for city number 139, cravo norte.
# ------------
# Processing Record for city number 140, ocean city.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 141, port elizabeth.
# ------------
# Processing Record for city number 142, luganville.
# ------------
# Processing Record for city number 143, nashville.
# ------------
# Processing Record for city number 144, dwarka.
# ------------
# Processing Record for city number 145, vila velha.
# ------------
# Processing Record for city number 146, otjimbingwe.
# ------------
# Processing Record for city number 147, benalla.
# ------------
# Processing Record for city number 148, keti bandar.
# ------------
# Processing Record for city number 149, chara.
# ------------
# Processing Record for city number 150, bengkulu.
# ------------
# Processing Record for city number 151, port hardy.
# ------------
# Processing Record for city number 152, kavaratti.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 153, ilulissat.
# ------------
# Processing Record for city number 154, kruisfontein.
# ------------
# Processing Record for city number 155, teguldet.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 156, adrar.
# ------------
# Processing Record for city number 157, luderitz.
# ------------
# Processing Record for city number 158, dali.
# ------------
# Processing Record for city number 159, siverek.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 160, palmares do sul.
# ------------
# Processing Record for city number 161, williamsburg.
# ------------
# Processing Record for city number 162, muli.
# ------------
# Processing Record for city number 163, saskylakh.
# ------------
# Processing Record for city number 164, saint-pierre.
# ------------
# Processing Record for city number 165, isangel.
# ------------
# Processing Record for city number 166, barao de melgaco.
# ------------
# Processing Record for city number 167, bethel.
# ------------
# Processing Record for city number 168, constitucion.
# ------------
# Processing Record for city number 169, huaiyin.
# ------------
# Processing Record for city number 170, oranjemund.
# ------------
# Processing Record for city number 171, clyde river.
# ------------
# Processing Record for city number 172, santa maria.
# ------------
# Processing Record for city number 173, rio grande.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 174, la romana.
# ------------
# Processing Record for city number 175, kavieng.
# ------------
# Processing Record for city number 176, resistencia.
# ------------
# Processing Record for city number 177, russell.
# ------------
# Processing Record for city number 178, kentville.
# ------------
# Processing Record for city number 179, qaanaaq.
# ------------
# Processing Record for city number 180, pauini.
# ------------
# Processing Record for city number 181, mahebourg.
# ------------
# Processing Record for city number 182, rudnaya pristan.
# ------------
# Processing Record for city number 183, celestun.
# ------------
# Processing Record for city number 184, fort nelson.
# ------------
# Processing Record for city number 185, yar-sale.
# ------------
# Processing Record for city number 186, ahipara.
# ------------
# Processing Record for city number 187, oga.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 188, fengrun.
# ------------
# Processing Record for city number 189, moroni.
# ------------
# Processing Record for city number 190, tongzi.
# ------------
# Processing Record for city number 191, ponta do sol.
# ------------
# Processing Record for city number 192, karratha.
# ------------
# Processing Record for city number 193, arman.
# ------------
# Processing Record for city number 194, kampot.
# ------------
# Processing Record for city number 195, nam dinh.
# ------------
# Processing Record for city number 196, castro.
# ------------
# Processing Record for city number 197, yinchuan.
# ------------
# Processing Record for city number 198, norman wells.
# ------------
# Processing Record for city number 199, thompson.
# ------------
# Processing Record for city number 200, butaritari.
# ------------
# Processing Record for city number 201, el alto.
# ------------
# Processing Record for city number 202, cabo san lucas.
# ------------
# Processing Record for city number 203, ngunguru.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 204, storforshei.
# ------------
# Processing Record for city number 205, conceicao do castelo.
# ------------
# Processing Record for city number 206, boguchany.
# ------------
# Processing Record for city number 207, lorengau.
# ------------
# Processing Record for city number 208, goderich.
# ------------
# Processing Record for city number 209, vila franca do campo.
# ------------
# Processing Record for city number 210, khowst.
# ------------
# Processing Record for city number 211, iqaluit.
# ------------
# Processing Record for city number 212, huoqiu.
# ------------
# Processing Record for city number 213, comodoro rivadavia.
# ------------
# Processing Record for city number 214, nizhniy kuranakh.
# ------------
# Processing Record for city number 215, barcelos.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 216, kaeo.
# ------------
# Processing Record for city number 217, dukat.
# ------------
# Processing Record for city number 218, ufimskiy.
# ------------
# Processing Record for city number 219, pacific grove.
# ------------
# Processing Record for city number 220, edwardsville.
# ------------
# Processing Record for city number 221, nizwa.
# ------------
# Processing Record for city number 222, lavrentiya.
# ------------
# Processing Record for city number 223, paysandu.
# ------------
# Processing Record for city number 224, kitakami.
# ------------
# Processing Record for city number 225, mandera.
# ------------
# Processing Record for city number 226, olinda.
# ------------
# Processing Record for city number 227, kiunga.
# ------------
# Processing Record for city number 228, arraial do cabo.
# ------------
# Processing Record for city number 229, caldwell.
# ------------
# Processing Record for city number 230, nyzhnya duvanka.
# ------------
# Processing Record for city number 231, mezhdurechensk.
# ------------
# Processing Record for city number 232, tabou.
# ------------
# Processing Record for city number 233, karasjok.
# ------------
# Processing Record for city number 234, takab.
# ------------
# Processing Record for city number 235, moerai.
# ------------
# Processing Record for city number 236, cherskiy.
# ------------
# Processing Record for city number 237, barrow.
# ------------
# Processing Record for city number 238, ostrovnoy.
# ------------
# Processing Record for city number 239, sioux lookout.
# ------------
# Processing Record for city number 240, biak.
# ------------
# Processing Record for city number 241, atuona.
# ------------
# Processing Record for city number 242, ust-nera.
# ------------
# Processing Record for city number 243, klatovy.
# ------------
# Processing Record for city number 244, airai.
# ------------
# Processing Record for city number 245, gobabis.
# ------------
# Processing Record for city number 246, coquimbo.
# ------------
# Processing Record for city number 247, san quintin.
# ------------
# Processing Record for city number 248, kununurra.
# ------------
# Processing Record for city number 249, hervey bay.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 250, palembang.
# ------------
# Processing Record for city number 251, henties bay.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 252, axim.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 253, oume.
# ------------
# Processing Record for city number 254, puerto carreno.
# ------------
# Processing Record for city number 255, puerto el triunfo.
# ------------
# Processing Record for city number 256, arkhangelsk.
# ------------
# Processing Record for city number 257, homer.
# ------------
# Processing Record for city number 258, ussel.
# ------------
# Processing Record for city number 259, monrovia.
# ------------
# Processing Record for city number 260, manzhouli.
# ------------
# Processing Record for city number 261, nova olimpia.
# ------------
# Processing Record for city number 262, carnarvon.
# ------------
# Processing Record for city number 263, guerrero negro.
# ------------
# Processing Record for city number 264, mezen.
# ------------
# Processing Record for city number 265, new norfolk.
# ------------
# Processing Record for city number 266, souillac.
# ------------
# Processing Record for city number 267, carnot.
# ------------
# Processing Record for city number 268, faanui.
# ------------
# Processing Record for city number 269, montes altos.
# ------------
# Processing Record for city number 270, solton.
# ------------
# Processing Record for city number 271, samarai.
# ------------
# Processing Record for city number 272, iskateley.
# ------------
# Processing Record for city number 273, makakilo city.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 274, hasaki.
# ------------
# Processing Record for city number 275, creel.
# ------------
# Processing Record for city number 276, necochea.
# ------------
# Processing Record for city number 277, marawi.
# ------------
# Processing Record for city number 278, severo-kurilsk.
# ------------
# Processing Record for city number 279, barranco.
# ------------
# Processing Record for city number 280, aromashevo.
# ------------
# Processing Record for city number 281, piopio.
# ------------
# Processing Record for city number 282, lerwick.
# ------------
# Processing Record for city number 283, port blair.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 284, margate.
# ------------
# Processing Record for city number 285, genhe.
# ------------
# Processing Record for city number 286, deputatskiy.
# ------------
# Processing Record for city number 287, onguday.
# ------------
# Processing Record for city number 288, aripuana.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 289, acarau.
# ------------
# Processing Record for city number 290, teahupoo.
# ------------
# Processing Record for city number 291, broome.
# ------------
# Processing Record for city number 292, biltine.
# ------------
# Processing Record for city number 293, provideniya.
# ------------
# Processing Record for city number 294, tautira.
# ------------
# Processing Record for city number 295, qui nhon.
# ------------
# Processing Record for city number 296, bage.
# ------------
# Processing Record for city number 297, saint-philippe.
# ------------
# Processing Record for city number 298, kuna.
# ------------
# Processing Record for city number 299, geilo.
# ------------
# Processing Record for city number 300, mounana.
# ------------
# Processing Record for city number 301, itaituba.
# ------------
# Processing Record for city number 302, san carlos de bariloche.
# ------------
# Processing Record for city number 303, port-cartier.
# ------------
# Processing Record for city number 304, beringovskiy.
# ------------
# Processing Record for city number 305, hendaye.
# ------------
# Processing Record for city number 306, riyadh.
# ------------
# Processing Record for city number 307, cap malheureux.
# ------------
# Processing Record for city number 308, ribeira grande.
# ------------
# Processing Record for city number 309, faya.
# ------------
# Processing Record for city number 310, honiara.
# ------------
# Processing Record for city number 311, pustoshka.
# ------------
# Processing Record for city number 312, deming.
# ------------
# Processing Record for city number 313, sambava.
# ------------
# Processing Record for city number 314, cozumel.
# ------------
# Processing Record for city number 315, verkhoshizhemye.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 316, pilar.
# ------------
# Processing Record for city number 317, manaure.
# ------------
# Processing Record for city number 318, beisfjord.
# ------------
# Processing Record for city number 319, mezhova.
# ------------
# Processing Record for city number 320, daru.
# ------------
# Processing Record for city number 321, chicama.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 322, hays.
# ------------
# Processing Record for city number 323, manzanillo.
# ------------
# Processing Record for city number 324, san roque.
# ------------
# Processing Record for city number 325, tura.
# ------------
# Processing Record for city number 326, victoria point.
# ------------
# Processing Record for city number 327, la ronge.
# ------------
# Processing Record for city number 328, calvinia.
# ------------
# Processing Record for city number 329, ciudad bolivar.
# ------------
# Processing Record for city number 330, bonthe.
# ------------
# Processing Record for city number 331, bathsheba.
# ------------
# Processing Record for city number 332, santiago de las vegas.
# ------------
# Processing Record for city number 333, kalawit.
# ------------
# Processing Record for city number 334, myrtle beach.
# ------------
# Processing Record for city number 335, padang.
# ------------
# Processing Record for city number 336, lagoa nova.
# ------------
# Processing Record for city number 337, touros.
# ------------
# Processing Record for city number 338, nyimba.
# ------------
# Processing Record for city number 339, sarankhola.
# ------------
# Processing Record for city number 340, high level.
# ------------
# Processing Record for city number 341, nome.
# ------------
# Processing Record for city number 342, lufilufi.
# ------------
# Processing Record for city number 343, hami.
# ------------
# Processing Record for city number 344, praia da vitoria.
# ------------
# Processing Record for city number 345, qasigiannguit.
# ------------
# Processing Record for city number 346, kutum.
# ------------
# Processing Record for city number 347, paamiut.
# ------------
# Processing Record for city number 348, nicoya.
# ------------
# Processing Record for city number 349, lujan.
# ------------
# Processing Record for city number 350, saldanha.
# ------------
# Processing Record for city number 351, onverwacht.
# ------------
# Processing Record for city number 352, talnakh.
# ------------
# Processing Record for city number 353, salinopolis.
# ------------
# Processing Record for city number 354, paita.
# ------------
# Processing Record for city number 355, grand-santi.
# ------------
# Processing Record for city number 356, galveston.
# ------------
# Processing Record for city number 357, dauriya.
# ------------
# Processing Record for city number 358, torbay.
# ------------
# Processing Record for city number 359, raga.
# ------------
# Processing Record for city number 360, mikkeli.
# ------------
# Processing Record for city number 361, kasempa.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 362, twentynine palms.
# ------------
# Processing Record for city number 363, akureyri.
# ------------
# Processing Record for city number 364, maymyo.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 365, salinas.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 366, bodden town.
# ------------
# Processing Record for city number 367, evensk.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 368, itarema.
# ------------
# Processing Record for city number 369, sept-iles.
# ------------
# Processing Record for city number 370, charlestown.
# ------------
# Processing Record for city number 371, kangaatsiaq.
# ------------
# Processing Record for city number 372, nyborg.
# ------------
# Processing Record for city number 373, balikpapan.
# ------------
# Processing Record for city number 374, dakar.
# ------------
# Processing Record for city number 375, litovko.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 376, juegang.
# ------------
# Processing Record for city number 377, alice springs.
# ------------
# Processing Record for city number 378, maltahohe.
# ------------
# Processing Record for city number 379, cidreira.
# ------------
# Processing Record for city number 380, dondo.
# ------------
# Processing Record for city number 381, hoi an.
# ------------
# Processing Record for city number 382, bo phloi.
# ------------
# Processing Record for city number 383, tilichiki.
# ------------
# Processing Record for city number 384, bauchi.
# ------------
# Processing Record for city number 385, serenje.
# ------------
# Processing Record for city number 386, kericho.
# ------------
# Processing Record for city number 387, codajas.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 388, itoman.
# ------------
# Processing Record for city number 389, komsomolskiy.
# ------------
# Processing Record for city number 390, hofn.
# ------------
# Processing Record for city number 391, shimoda.
# ------------
# Processing Record for city number 392, altay.
# ------------
# Processing Record for city number 393, mount gambier.
# ------------
# Processing Record for city number 394, nebaj.
# ------------
# Processing Record for city number 395, dafeng.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 396, edremit.
# ------------
# Processing Record for city number 397, sterling.
# ------------
# Processing Record for city number 398, vaitape.
# ------------
# Processing Record for city number 399, sao joao da barra.
# ------------
# Processing Record for city number 400, calbuco.
# ------------
# Processing Record for city number 401, kijang.
# ------------
# Processing Record for city number 402, olafsvik.
# ------------
# Processing Record for city number 403, sola.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 404, hamilton.
# ------------
# Processing Record for city number 405, nikel.
# ------------
# Processing Record for city number 406, chiredzi.
# ------------
# Processing Record for city number 407, mathathane.
# ------------
# Processing Record for city number 408, muros.
# ------------
# Processing Record for city number 409, nanortalik.
# ------------
# Processing Record for city number 410, goundam.
# ------------
# Processing Record for city number 411, viedma.
# ------------
# Processing Record for city number 412, naze.
# ------------
# Processing Record for city number 413, kloulklubed.
# ------------
# Processing Record for city number 414, assiniboia.
# ------------
# Processing Record for city number 415, hambantota.
# ------------
# Processing Record for city number 416, bakel.
# ------------
# Processing Record for city number 417, daitari.
# ------------
# Processing Record for city number 418, lesosibirsk.
# ------------
# Processing Record for city number 419, esperance.
# ------------
# Processing Record for city number 420, jardim.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 421, shimanovsk.
# ------------
# Processing Record for city number 422, kargil.
# ------------
# Processing Record for city number 423, egvekinot.
# ------------
# Processing Record for city number 424, mosetse.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 425, abu samrah.
# ------------
# Processing Record for city number 426, taoudenni.
# ------------
# Processing Record for city number 427, lompoc.
# ------------
# Processing Record for city number 428, berberati.
# ------------
# Processing Record for city number 429, hamcearca.
# ------------
# Processing Record for city number 430, utkivka.
# ------------
# Processing Record for city number 431, anqiu.
# ------------
# Processing Record for city number 432, oxelosund.
# ------------
# Processing Record for city number 433, teya.
# ------------
# Processing Record for city number 434, saint-augustin.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 435, manbij.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 436, zhigansk.
# ------------
# Processing Record for city number 437, hauterive.
# ------------
# Processing Record for city number 438, san andres.
# ------------
# Processing Record for city number 439, oistins.
# ------------
# Processing Record for city number 440, nhulunbuy.
# ------------
# Processing Record for city number 441, asau.
# ------------
# Processing Record for city number 442, usinsk.
# ------------
# Processing Record for city number 443, panguna.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 444, xiuyan.
# ------------
# Processing Record for city number 445, la cruz.
# ------------
# Processing Record for city number 446, palmer.
# ------------
# Processing Record for city number 447, beatrice.
# ------------
# Processing Record for city number 448, guozhen.
# ------------
# Processing Record for city number 449, vitim.
# ------------
# Processing Record for city number 450, urdoma.
# ------------
# Processing Record for city number 451, monterey.
# ------------
# Processing Record for city number 452, bardiyah.
# ------------
# Processing Record for city number 453, shu.
# ------------
# Processing Record for city number 454, helsinge.
# ------------
# Processing Record for city number 455, nouadhibou.
# ------------
# Processing Record for city number 456, yuli.
# ------------
# Processing Record for city number 457, tecoanapa.
# ------------
# Processing Record for city number 458, pangkalanbuun.
# ------------
# Processing Record for city number 459, snasa.
# ------------
# Processing Record for city number 460, santa lucia.
# ------------
# Processing Record for city number 461, akdepe.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 462, seoul.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 463, honningsvag.
# ------------
# Processing Record for city number 464, kulhudhuffushi.
# ------------
# Processing Record for city number 465, brooklyn park.
# ------------
# Processing Record for city number 466, port lincoln.
# ------------
# Processing Record for city number 467, gravelbourg.
# ------------
# Processing Record for city number 468, taman.
# ------------
# Processing Record for city number 469, cap-aux-meules.
# ------------
# Processing Record for city number 470, boa vista.
# ------------
# Processing Record for city number 471, virginia beach.
# ------------
# Processing Record for city number 472, okahandja.
# ------------
# Processing Record for city number 473, fortuna.
# ------------
# Processing Record for city number 474, kharp.
# ------------
# Processing Record for city number 475, nehe.
# ------------
# Processing Record for city number 476, togur.
# ------------
# Processing Record for city number 477, progreso.
# ------------
# Processing Record for city number 478, killybegs.
# ------------
# Processing Record for city number 479, ucluelet.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 480, champerico.
# ------------
# Processing Record for city number 481, nelson bay.
# ------------
# Processing Record for city number 482, quatre cocos.
# ------------
# Processing Record for city number 483, durban.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 484, kirando.
# ------------
# Processing Record for city number 485, ust-koksa.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 486, magadan.
# ------------
# Processing Record for city number 487, gizo.
# ------------
# Processing Record for city number 488, gritsovskiy.
# ------------
# Processing Record for city number 489, rio negrinho.
# ------------
# Processing Record for city number 490, matinha.
# ------------
# Processing Record for city number 491, camacha.
# ------------
# Processing Record for city number 492, northam.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 493, mugur-aksy.
# ------------
# Processing Record for city number 494, kroya.
# ------------
# Processing Record for city number 495, kichera.
# ------------
# Processing Record for city number 496, caravelas.
# ------------
# Processing Record for city number 497, bambanglipuro.
# ------------
# Processing Record for city number 498, conner.
# ------------
# Processing Record for city number 499, portsmouth.
# ------------
# Processing Record for city number 500, uruzgan.
# ------------
# Processing Record for city number 501, yichun.
# ------------
# Processing Record for city number 502, katihar.
# ------------
# Processing Record for city number 503, aborlan.
# ------------
# Processing Record for city number 504, lesnoy.
# ------------
# Processing Record for city number 505, oranjestad.
# ------------
# Processing Record for city number 506, salekhard.
# ------------
# Processing Record for city number 507, ruteng.
# ------------
# Processing Record for city number 508, hualmay.
# ------------
# Processing Record for city number 509, ahuimanu.
# ------------
# Processing Record for city number 510, basoko.
# ------------
# Processing Record for city number 511, dera ghazi khan.
# ------------
# Processing Record for city number 512, labuhan.
# ------------
# Processing Record for city number 513, wuwei.
# ------------
# Processing Record for city number 514, ulkan.
# ------------
# Processing Record for city number 515, cafarnaum.
# ------------
# Processing Record for city number 516, shitanjing.
# ------------
# Processing Record for city number 517, sauda.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 518, kasamwa.
# ------------
# Processing Record for city number 519, sabang.
# ------------
# Processing Record for city number 520, kasongo-lunda.
# ------------
# Processing Record for city number 521, paraguari.
# ------------
# Processing Record for city number 522, the pas.
# ------------
# Processing Record for city number 523, tecolutla.
# ------------
# Processing Record for city number 524, bongandanga.
# ------------
# Processing Record for city number 525, mago.
# ------------
# Processing Record for city number 526, bilibino.
# ------------
# Processing Record for city number 527, huambo.
# ------------
# Processing Record for city number 528, atar.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 529, nuuk.
# ------------
# Processing Record for city number 530, unai.
# ------------
# Processing Record for city number 531, anito.
# ------------
# Processing Record for city number 532, waipawa.
# ------------
# Processing Record for city number 533, cabedelo.
# ------------
# Processing Record for city number 534, grand junction.
# ------------
# Processing Record for city number 535, nieves.
# ------------
# Processing Record for city number 536, elliot lake.
# ------------
# Processing Record for city number 537, staryy nadym.
# ------------
# Processing Record for city number 538, ambositra.
# ------------
# Processing Record for city number 539, birjand.
# ------------
# Processing Record for city number 540, kailua.
# ------------
# Processing Record for city number 541, warrington.
# ------------
# Processing Record for city number 542, turki.
# ------------
# Processing Record for city number 543, mawlaik.
# ------------
# Processing Record for city number 544, rivera.
# ------------
# Processing Record for city number 545, san-pedro.
# ------------
# Processing Record for city number 546, poum.
# ------------
# Processing Record for city number 547, knysna.
# ------------
# Processing Record for city number 548, auki.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 549, cooma.
# ------------
# Processing Record for city number 550, shakawe.
# ------------
# Processing Record for city number 551, dunedin.
# ------------
# Processing Record for city number 552, tucuma.
# ------------
# Processing Record for city number 553, bogatic.
# ------------
# Processing Record for city number 554, khislavichi.
# ------------
# Processing Record for city number 555, okhotsk.
# ------------
# Processing Record for city number 556, half moon bay.
# ------------
# Processing Record for city number 557, gerzat.
# ------------
# Processing Record for city number 558, gimli.
# ------------
# Processing Record for city number 559, acheng.
# ------------
# Processing Record for city number 560, mogadishu.
# ------------
# Processing Record for city number 561, vanimo.
# ------------
# Processing Record for city number 562, ixtapa.
# ------------
# Processing Record for city number 563, namtsy.
# ------------
# Processing Record for city number 564, belyy.
# ------------
# Processing Record for city number 565, lixourion.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 566, bagan.
# ------------
# Processing Record for city number 567, martapura.
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Build and display the dataFrame
weather_dict = {
    "City": cityname,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date" : date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":windspeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %%
weather_data
# Out:
#             City  Cloudiness Country                      Date  Humidity  \
# 0        Mataura         100      NZ  Sun Apr 12 11:55:55 2020        90
# 1    George Town          20      MY  Sun Apr 12 11:55:55 2020        83
# 2      Tuatapere         100      NZ  Sun Apr 12 11:55:55 2020        90
# 3      Grindavik          90      IS  Sun Apr 12 11:55:56 2020       100
# 4        Sibolga         100      ID  Sun Apr 12 11:55:56 2020        79
# ..           ...         ...     ...                       ...       ...
# 562       Namtsy           1      RU  Sun Apr 12 11:57:40 2020        92
# 563        Belyy          98      RU  Sun Apr 12 11:57:40 2020        64
# 564      Lixouri           0      GR  Sun Apr 12 11:57:41 2020        40
# 565        Bagan          88      RU  Sun Apr 12 11:57:41 2020        90
# 566    Martapura          40      ID  Sun Apr 12 11:57:41 2020       100
#
#        Lat     Lng  Max Temp  Wind Speed
# 0   -46.19  168.86     46.00        5.99
# 1     5.41  100.34     84.20        5.82
# 2   -46.13  167.68     46.00        5.99
# 3    63.84  -22.43     46.40       20.80
# 4     1.74   98.78     78.96        1.66
# ..     ...     ...       ...         ...
# 562  62.72  129.67     32.00       13.42
# 563  55.84   32.94     40.66        5.30
# 564  38.20   20.43     73.40        6.93
# 565  54.10   77.66     34.68       12.08
# 566  -3.42  114.85     78.80        3.36
#
# [567 rows x 9 columns]

# %%
#Export the Dataframe to a csv file located in output_data folder
weather_data.to_csv("../output_data/cities.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for Max temperature vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Max Temp']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(F)')
plt.title('City Latitude vs Max Temperature 04/12/2020')
plt.savefig("../output_data/fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for Humidity vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Humidity']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs Humidity 04/12/2020')
plt.savefig("../output_data/fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a Scatter Plot for Clodiness vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Cloudiness']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs Cloudiness 04/12/2020')
plt.savefig("../output_data/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a Scatter Plot for Wind Speed vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Wind Speed']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('City Latitude vs Wind Speed 04/12/2020')
plt.savefig("../output_data/fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northerncities=weather_data.loc[weather_data["Lat"]>=0.0]
southerncities=weather_data.loc[weather_data["Lat"]<0.0]
northerncities.reset_index(inplace=True)
southerncities.reset_index(inplace=True)
southerncities.head()
# Out:
#    index          City  Cloudiness Country                      Date  \
# 0      0       Mataura         100      NZ  Sun Apr 12 11:55:55 2020
# 1      2     Tuatapere         100      NZ  Sun Apr 12 11:55:55 2020
# 2      5  Punta Arenas          40      CL  Sun Apr 12 11:54:17 2020
# 3      7    Kaitangata          95      NZ  Sun Apr 12 11:55:56 2020
# 4      8  Christchurch           8      NZ  Sun Apr 12 11:55:17 2020
#
#    Humidity    Lat     Lng  Max Temp  Wind Speed
# 0        90 -46.19  168.86      46.0        5.99
# 1        90 -46.13  167.68      46.0        5.99
# 2        71 -53.15  -70.92      51.8       24.16
# 3        86 -46.28  169.85      46.0        1.99
# 4        55 -43.53  172.63      63.0       11.41

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linearreg(x_val, y_val, x_label, y_label,posn, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
    regress_values = x_val * slope + intercept
    print(f"The r-squared is: {rvalue**2}")
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_val,y_val)
    plt.plot(x_val,regress_values,"r-")
    plt.annotate(line_eq,posn,fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Max Temp vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Max Temp"]
x_label= "Lat"
y_label= "Max Temp"
posn=(6,10)
title="Northern Hemisphere Max Temp vs Lat"
linearreg(x_val, y_val, x_label, y_label, posn,title)
plt.savefig("../output_data/fig5.png")
# Out:
# The r-squared is: 0.783727645955073

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Max Temp vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Max Temp"]
x_label= "Lat"
y_label= "Max Temp"
posn=(-30,35)
title="Southern Hemisphere Max Temp vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig6.png")
# Out:
# The r-squared is: 0.5505930413888215

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Humidity vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Humidity"]
x_label= "Lat"
y_label= "Humidity (%)"
posn=(45,12)
title="Northern Hemisphere Humidity vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig7.png")
# Out:
# The r-squared is: 0.10785347555354828

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Humidity vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Humidity"]
x_label= "Lat"
y_label= "Humidity (%)"
posn=(-22,20)
title="Southern Hemisphere Humidity vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig8.png")
# Out:
# The r-squared is: 0.009657066483996708

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Cloudiness vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Cloudiness"]
x_label= "Lat"
y_label= "Cloudiness (%)"
posn=(34,30)
title="Northern Hemisphere Cloudiness vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig9.png")
# Out:
# The r-squared is: 0.024483271595827423

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Cloudiness vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Cloudiness"]
x_label= "Lat"
y_label= "Cloudiness (%)"
posn=(-22,10)
title="Southern Hemisphere Cloudiness vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig10.png")
# Out:
# The r-squared is: 0.03583392398763772

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Wind Speed vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Wind Speed"]
x_label= "Lat"
y_label= "Wind Speed (mph)"
posn=(1,28)
title="Northern Hemisphere Wind Speed vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig11.png")
# Out:
# The r-squared is: 0.020014737044961938

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Wind Speed vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Wind Speed"]
x_label= "Lat"
y_label= "Wind Speed (mph)"
posn=(-22,30)
title="Southern Hemisphere Wind Speed vs Lat"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig12.png")
# Out:
# The r-squared is: 0.0754158665076049
