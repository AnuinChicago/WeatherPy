# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\aguha\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\aguha\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from time import ctime as convert

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url="http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# set up lists to hold reponse info
cityname=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
lat = []
lng=[]
max_temp = []
windspeed=[]

#setup counter
count=1

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        cityname.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        #date.append(convert(int(response['dt'])))
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        windspeed.append(response['wind']['speed'])
        print(f"Processing Record for city number {count}, {city}.")
        count= count +1
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Processing Record for city number 1, leningradskiy.
# ------------
# Processing Record for city number 2, vanimo.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 3, erzin.
# ------------
# Processing Record for city number 4, radomir.
# ------------
# Processing Record for city number 5, mar del plata.
# ------------
# Processing Record for city number 6, san miguel.
# ------------
# Processing Record for city number 7, fallon.
# ------------
# Processing Record for city number 8, shahr-e babak.
# ------------
# Processing Record for city number 9, lorengau.
# ------------
# Processing Record for city number 10, port lincoln.
# ------------
# Processing Record for city number 11, grafton.
# ------------
# Processing Record for city number 12, busselton.
# ------------
# Processing Record for city number 13, lebu.
# ------------
# Processing Record for city number 14, provideniya.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 15, atuona.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 16, narsaq.
# ------------
# Processing Record for city number 17, punta arenas.
# ------------
# Processing Record for city number 18, mataura.
# ------------
# Processing Record for city number 19, dikson.
# ------------
# Processing Record for city number 20, kapaa.
# ------------
# Processing Record for city number 21, hilo.
# ------------
# Processing Record for city number 22, lavrentiya.
# ------------
# Processing Record for city number 23, souillac.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 24, mount isa.
# ------------
# Processing Record for city number 25, port alfred.
# ------------
# Processing Record for city number 26, mount gambier.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 27, fernie.
# ------------
# Processing Record for city number 28, bayan.
# ------------
# Processing Record for city number 29, hermanus.
# ------------
# Processing Record for city number 30, kodiak.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 31, hasaki.
# ------------
# Processing Record for city number 32, tuktoyaktuk.
# ------------
# Processing Record for city number 33, hambantota.
# ------------
# Processing Record for city number 34, butaritari.
# ------------
# Processing Record for city number 35, cheremukhovo.
# ------------
# Processing Record for city number 36, husavik.
# ------------
# Processing Record for city number 37, entre rios.
# ------------
# Processing Record for city number 38, albany.
# ------------
# Processing Record for city number 39, pochutla.
# ------------
# Processing Record for city number 40, itoman.
# ------------
# Processing Record for city number 41, norman wells.
# ------------
# Processing Record for city number 42, tygda.
# ------------
# Processing Record for city number 43, port blair.
# ------------
# Processing Record for city number 44, abomsa.
# ------------
# Processing Record for city number 45, bluff.
# ------------
# Processing Record for city number 46, new norfolk.
# ------------
# Processing Record for city number 47, tommot.
# ------------
# Processing Record for city number 48, vaini.
# ------------
# Processing Record for city number 49, rikitea.
# ------------
# Processing Record for city number 50, airai.
# ------------
# Processing Record for city number 51, qasigiannguit.
# ------------
# Processing Record for city number 52, jamestown.
# ------------
# Processing Record for city number 53, sinnamary.
# ------------
# Processing Record for city number 54, cabo san lucas.
# ------------
# Processing Record for city number 55, bambous virieux.
# ------------
# Processing Record for city number 56, belmonte.
# ------------
# Processing Record for city number 57, san patricio.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 58, ancud.
# ------------
# Processing Record for city number 59, slave lake.
# ------------
# Processing Record for city number 60, yashkul.
# ------------
# Processing Record for city number 61, cape town.
# ------------
# Processing Record for city number 62, grasse.
# ------------
# Processing Record for city number 63, mandalgovi.
# ------------
# Processing Record for city number 64, chuy.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 65, vao.
# ------------
# Processing Record for city number 66, taft.
# ------------
# Processing Record for city number 67, itarema.
# ------------
# Processing Record for city number 68, nanortalik.
# ------------
# Processing Record for city number 69, sur.
# ------------
# Processing Record for city number 70, hobart.
# ------------
# Processing Record for city number 71, north bend.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 72, macamic.
# ------------
# Processing Record for city number 73, harper.
# ------------
# Processing Record for city number 74, tuatapere.
# ------------
# Processing Record for city number 75, kavieng.
# ------------
# Processing Record for city number 76, gari.
# ------------
# Processing Record for city number 77, granada.
# ------------
# Processing Record for city number 78, pisco.
# ------------
# Processing Record for city number 79, saint-philippe.
# ------------
# Processing Record for city number 80, terrace bay.
# ------------
# Processing Record for city number 81, traralgon.
# ------------
# Processing Record for city number 82, north battleford.
# ------------
# Processing Record for city number 83, newport.
# ------------
# Processing Record for city number 84, shelburne.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 85, phetchabun.
# ------------
# Processing Record for city number 86, ushuaia.
# ------------
# Processing Record for city number 87, upernavik.
# ------------
# Processing Record for city number 88, nikolskoye.
# ------------
# Processing Record for city number 89, whitehorse.
# ------------
# Processing Record for city number 90, gympie.
# ------------
# Processing Record for city number 91, lerwick.
# ------------
# Processing Record for city number 92, yellowknife.
# ------------
# Processing Record for city number 93, faanui.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 94, tabou.
# ------------
# Processing Record for city number 95, bulawayo.
# ------------
# Processing Record for city number 96, khatanga.
# ------------
# Processing Record for city number 97, camacha.
# ------------
# Processing Record for city number 98, port elizabeth.
# ------------
# Processing Record for city number 99, shenjiamen.
# ------------
# Processing Record for city number 100, umm lajj.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 101, muscat.
# ------------
# Processing Record for city number 102, guerrero negro.
# ------------
# Processing Record for city number 103, esperance.
# ------------
# Processing Record for city number 104, kudahuvadhoo.
# ------------
# Processing Record for city number 105, barrow.
# ------------
# Processing Record for city number 106, kaitangata.
# ------------
# Processing Record for city number 107, puerto ayora.
# ------------
# Processing Record for city number 108, kahului.
# ------------
# Processing Record for city number 109, redlands.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 110, catuday.
# ------------
# Processing Record for city number 111, aswan.
# ------------
# Processing Record for city number 112, havelock.
# ------------
# Processing Record for city number 113, bandarbeyla.
# ------------
# Processing Record for city number 114, cherskiy.
# ------------
# Processing Record for city number 115, qaanaaq.
# ------------
# Processing Record for city number 116, chokurdakh.
# ------------
# Processing Record for city number 117, praia da vitoria.
# ------------
# Processing Record for city number 118, belyy yar.
# ------------
# Processing Record for city number 119, carnarvon.
# ------------
# Processing Record for city number 120, minab.
# ------------
# Processing Record for city number 121, saint-leu.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 122, bredasdorp.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 123, orocue.
# ------------
# Processing Record for city number 124, kibala.
# ------------
# Processing Record for city number 125, komsomolskiy.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 126, marsa matruh.
# ------------
# Processing Record for city number 127, bilibino.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 128, mahebourg.
# ------------
# Processing Record for city number 129, aromashevo.
# ------------
# Processing Record for city number 130, lasa.
# ------------
# Processing Record for city number 131, liverpool.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 132, ribeira grande.
# ------------
# Processing Record for city number 133, abu samrah.
# ------------
# Processing Record for city number 134, boa vista.
# ------------
# Processing Record for city number 135, dmitriyevka.
# ------------
# Processing Record for city number 136, birao.
# ------------
# Processing Record for city number 137, suntar.
# ------------
# Processing Record for city number 138, porto novo.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 139, ixtapa.
# ------------
# Processing Record for city number 140, taoudenni.
# ------------
# Processing Record for city number 141, gat.
# ------------
# Processing Record for city number 142, araouane.
# ------------
# Processing Record for city number 143, merauke.
# ------------
# Processing Record for city number 144, natal.
# ------------
# Processing Record for city number 145, teeli.
# ------------
# Processing Record for city number 146, coihaique.
# ------------
# Processing Record for city number 147, georgetown.
# ------------
# Processing Record for city number 148, dwarka.
# ------------
# Processing Record for city number 149, clyde river.
# ------------
# Processing Record for city number 150, kurilsk.
# ------------
# Processing Record for city number 151, meulaboh.
# ------------
# Processing Record for city number 152, agadir.
# ------------
# Processing Record for city number 153, vysokogornyy.
# ------------
# Processing Record for city number 154, caravelas.
# ------------
# Processing Record for city number 155, wanning.
# ------------
# Processing Record for city number 156, norwich.
# ------------
# Processing Record for city number 157, paso de los toros.
# ------------
# Processing Record for city number 158, sorland.
# ------------
# Processing Record for city number 159, novobirilyussy.
# ------------
# Processing Record for city number 160, mumford.
# ------------
# Processing Record for city number 161, eenhana.
# ------------
# Processing Record for city number 162, avarua.
# ------------
# Processing Record for city number 163, sao filipe.
# ------------
# Processing Record for city number 164, castro.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 165, sept-iles.
# ------------
# Processing Record for city number 166, mitsamiouli.
# ------------
# Processing Record for city number 167, gerede.
# ------------
# Processing Record for city number 168, bara.
# ------------
# Processing Record for city number 169, auki.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 170, bethel.
# ------------
# Processing Record for city number 171, salinopolis.
# ------------
# Processing Record for city number 172, zhuanghe.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 173, bela.
# ------------
# Processing Record for city number 174, sobolevo.
# ------------
# Processing Record for city number 175, plouzane.
# ------------
# Processing Record for city number 176, atchison.
# ------------
# Processing Record for city number 177, bullas.
# ------------
# Processing Record for city number 178, macia.
# ------------
# Processing Record for city number 179, padang.
# ------------
# Processing Record for city number 180, altoona.
# ------------
# Processing Record for city number 181, victoria.
# ------------
# Processing Record for city number 182, westport.
# ------------
# Processing Record for city number 183, issenye.
# ------------
# Processing Record for city number 184, de aar.
# ------------
# Processing Record for city number 185, pedasi.
# ------------
# Processing Record for city number 186, tessalit.
# ------------
# Processing Record for city number 187, port macquarie.
# ------------
# Processing Record for city number 188, pevek.
# ------------
# Processing Record for city number 189, thompson.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 190, tevriz.
# ------------
# Processing Record for city number 191, tianpeng.
# ------------
# Processing Record for city number 192, saskylakh.
# ------------
# Processing Record for city number 193, nawa.
# ------------
# Processing Record for city number 194, maridi.
# ------------
# Processing Record for city number 195, biysk.
# ------------
# Processing Record for city number 196, camana.
# ------------
# Processing Record for city number 197, flin flon.
# ------------
# Processing Record for city number 198, japura.
# ------------
# Processing Record for city number 199, tasiilaq.
# ------------
# Processing Record for city number 200, saldanha.
# ------------
# Processing Record for city number 201, bengkulu.
# ------------
# Processing Record for city number 202, vila franca do campo.
# ------------
# Processing Record for city number 203, tomohon.
# ------------
# Processing Record for city number 204, tres arroyos.
# ------------
# Processing Record for city number 205, kokstad.
# ------------
# Processing Record for city number 206, bud.
# ------------
# Processing Record for city number 207, artvin.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 208, san cristobal.
# ------------
# Processing Record for city number 209, goderich.
# ------------
# Processing Record for city number 210, tigil.
# ------------
# Processing Record for city number 211, vestmannaeyjar.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 212, kudirkos naumiestis.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 213, pilar.
# ------------
# Processing Record for city number 214, petropavlovsk-kamchatskiy.
# ------------
# Processing Record for city number 215, fortuna.
# ------------
# Processing Record for city number 216, los llanos de aridane.
# ------------
# Processing Record for city number 217, berlevag.
# ------------
# Processing Record for city number 218, atambua.
# ------------
# Processing Record for city number 219, progreso.
# ------------
# Processing Record for city number 220, bowling green.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 221, keti bandar.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 222, thinadhoo.
# ------------
# Processing Record for city number 223, umm kaddadah.
# ------------
# Processing Record for city number 224, moron.
# ------------
# Processing Record for city number 225, otjimbingwe.
# ------------
# Processing Record for city number 226, lampazos de naranjo.
# ------------
# Processing Record for city number 227, pafos.
# ------------
# Processing Record for city number 228, broome.
# ------------
# Processing Record for city number 229, tiksi.
# ------------
# Processing Record for city number 230, reinosa.
# ------------
# Processing Record for city number 231, kalmar.
# ------------
# Processing Record for city number 232, sterling.
# ------------
# Processing Record for city number 233, namatanai.
# ------------
# Processing Record for city number 234, karratha.
# ------------
# Processing Record for city number 235, eyrarbakki.
# ------------
# Processing Record for city number 236, adrar.
# ------------
# Processing Record for city number 237, klaksvik.
# ------------
# Processing Record for city number 238, lashio.
# ------------
# Processing Record for city number 239, san jeronimo.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 240, blomberg.
# ------------
# Processing Record for city number 241, richards bay.
# ------------
# Processing Record for city number 242, pavlivka.
# ------------
# Processing Record for city number 243, kawalu.
# ------------
# Processing Record for city number 244, sturgeon bay.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 245, smithers.
# ------------
# Processing Record for city number 246, santiago.
# ------------
# Processing Record for city number 247, bethanien.
# ------------
# Processing Record for city number 248, charlestown.
# ------------
# Processing Record for city number 249, constitucion.
# ------------
# Processing Record for city number 250, yar-sale.
# ------------
# Processing Record for city number 251, santa cruz.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 252, kasongo-lunda.
# ------------
# Processing Record for city number 253, ladario.
# ------------
# Processing Record for city number 254, torbay.
# ------------
# Processing Record for city number 255, ahipara.
# ------------
# Processing Record for city number 256, kalaleh.
# ------------
# Processing Record for city number 257, iqaluit.
# ------------
# Processing Record for city number 258, chingirlau.
# ------------
# Processing Record for city number 259, kupino.
# ------------
# Processing Record for city number 260, douglas.
# ------------
# Processing Record for city number 261, hamilton.
# ------------
# Processing Record for city number 262, portland.
# ------------
# Processing Record for city number 263, jiblah.
# ------------
# Processing Record for city number 264, bagdarin.
# ------------
# Processing Record for city number 265, kaura namoda.
# ------------
# Processing Record for city number 266, lagoa.
# ------------
# Processing Record for city number 267, exeter.
# ------------
# Processing Record for city number 268, avelgem.
# ------------
# Processing Record for city number 269, svetlaya.
# ------------
# Processing Record for city number 270, codrington.
# ------------
# Processing Record for city number 271, sola.
# ------------
# Processing Record for city number 272, lulea.
# ------------
# Processing Record for city number 273, wanaka.
# ------------
# Processing Record for city number 274, fuxin.
# ------------
# Processing Record for city number 275, hithadhoo.
# ------------
# Processing Record for city number 276, longyearbyen.
# ------------
# Processing Record for city number 277, falkenberg.
# ------------
# Processing Record for city number 278, ilhabela.
# ------------
# Processing Record for city number 279, esmeraldas.
# ------------
# Processing Record for city number 280, roald.
# ------------
# Processing Record for city number 281, nemuro.
# ------------
# Processing Record for city number 282, burnie.
# ------------
# Processing Record for city number 283, vendychany.
# ------------
# Processing Record for city number 284, mosquera.
# ------------
# Processing Record for city number 285, nuuk.
# ------------
# Processing Record for city number 286, arkhara.
# ------------
# Processing Record for city number 287, barbacoas.
# ------------
# Processing Record for city number 288, samfya.
# ------------
# Processing Record for city number 289, trinidad.
# ------------
# Processing Record for city number 290, luocheng.
# ------------
# Processing Record for city number 291, hargeysa.
# ------------
# Processing Record for city number 292, washim.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 293, mao.
# ------------
# Processing Record for city number 294, zaysan.
# ------------
# Processing Record for city number 295, yichang.
# ------------
# Processing Record for city number 296, thabazimbi.
# ------------
# Processing Record for city number 297, amlagora.
# ------------
# Processing Record for city number 298, camacupa.
# ------------
# Processing Record for city number 299, tabas.
# ------------
# Processing Record for city number 300, vostok.
# ------------
# Processing Record for city number 301, port-gentil.
# ------------
# Processing Record for city number 302, sitka.
# ------------
# Processing Record for city number 303, laguna.
# ------------
# Processing Record for city number 304, paamiut.
# ------------
# Processing Record for city number 305, alofi.
# ------------
# Processing Record for city number 306, astana.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 307, moose factory.
# ------------
# Processing Record for city number 308, waupun.
# ------------
# Processing Record for city number 309, talnakh.
# ------------
# Processing Record for city number 310, isangel.
# ------------
# Processing Record for city number 311, kindu.
# ------------
# Processing Record for city number 312, nome.
# ------------
# Processing Record for city number 313, waverly.
# ------------
# Processing Record for city number 314, novyy svit.
# ------------
# Processing Record for city number 315, puerto del rosario.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 316, karatau.
# ------------
# Processing Record for city number 317, sorong.
# ------------
# Processing Record for city number 318, almaznyy.
# ------------
# Processing Record for city number 319, santa marinella.
# ------------
# Processing Record for city number 320, bremerton.
# ------------
# Processing Record for city number 321, east london.
# ------------
# Processing Record for city number 322, saint anthony.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 323, lodja.
# ------------
# Processing Record for city number 324, saint george.
# ------------
# Processing Record for city number 325, nizhniy kuranakh.
# ------------
# Processing Record for city number 326, taltal.
# ------------
# Processing Record for city number 327, ilulissat.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 328, akureyri.
# ------------
# Processing Record for city number 329, kang.
# ------------
# Processing Record for city number 330, yaan.
# ------------
# Processing Record for city number 331, asyut.
# ------------
# Processing Record for city number 332, san andres.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 333, pyay.
# ------------
# Processing Record for city number 334, yarim.
# ------------
# Processing Record for city number 335, birjand.
# ------------
# Processing Record for city number 336, vardo.
# ------------
# Processing Record for city number 337, laranjeiras do sul.
# ------------
# Processing Record for city number 338, palaikastron.
# ------------
# Processing Record for city number 339, sibolga.
# ------------
# Processing Record for city number 340, nagua.
# ------------
# Processing Record for city number 341, mujiayingzi.
# ------------
# Processing Record for city number 342, sao miguel do araguaia.
# ------------
# Processing Record for city number 343, korla.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 344, lumut.
# ------------
# Processing Record for city number 345, marawi.
# ------------
# Processing Record for city number 346, havre-saint-pierre.
# ------------
# Processing Record for city number 347, port hawkesbury.
# ------------
# Processing Record for city number 348, katsuura.
# ------------
# Processing Record for city number 349, oussouye.
# ------------
# Processing Record for city number 350, lompoc.
# ------------
# Processing Record for city number 351, kavaratti.
# ------------
# Processing Record for city number 352, skibbereen.
# ------------
# Processing Record for city number 353, batagay-alyta.
# ------------
# Processing Record for city number 354, srednekolymsk.
# ------------
# Processing Record for city number 355, zunyi.
# ------------
# Processing Record for city number 356, lexington.
# ------------
# Processing Record for city number 357, baiyin.
# ------------
# Processing Record for city number 358, ivanjica.
# ------------
# Processing Record for city number 359, sibu.
# ------------
# Processing Record for city number 360, faya.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 361, altamira.
# ------------
# Processing Record for city number 362, jacareacanga.
# ------------
# Processing Record for city number 363, qaqortoq.
# ------------
# Processing Record for city number 364, hobyo.
# ------------
# Processing Record for city number 365, pouembout.
# ------------
# Processing Record for city number 366, mackenzie.
# ------------
# Processing Record for city number 367, tucupita.
# ------------
# Processing Record for city number 368, pietarsaari.
# ------------
# Processing Record for city number 369, anchorage.
# ------------
# Processing Record for city number 370, russell.
# ------------
# Processing Record for city number 371, dhidhdhoo.
# ------------
# Processing Record for city number 372, chagoda.
# ------------
# Processing Record for city number 373, campos novos.
# ------------
# Processing Record for city number 374, kilifi.
# ------------
# Processing Record for city number 375, rasmiresti.
# ------------
# Processing Record for city number 376, ejido.
# ------------
# Processing Record for city number 377, nawabganj.
# ------------
# Processing Record for city number 378, arraial do cabo.
# ------------
# Processing Record for city number 379, ishigaki.
# ------------
# Processing Record for city number 380, hualmay.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 381, sioux lookout.
# ------------
# Processing Record for city number 382, galle.
# ------------
# Processing Record for city number 383, zhezkazgan.
# ------------
# Processing Record for city number 384, khani.
# ------------
# Processing Record for city number 385, barstow.
# ------------
# Processing Record for city number 386, soyo.
# ------------
# Processing Record for city number 387, staryy nadym.
# ------------
# Processing Record for city number 388, fairbanks.
# ------------
# Processing Record for city number 389, ranong.
# ------------
# Processing Record for city number 390, arsenyev.
# ------------
# Processing Record for city number 391, okha.
# ------------
# Processing Record for city number 392, tura.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 393, aykhal.
# ------------
# Processing Record for city number 394, jambi.
# ------------
# Processing Record for city number 395, coquimbo.
# ------------
# Processing Record for city number 396, harnosand.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 397, scarborough.
# ------------
# Processing Record for city number 398, margate.
# ------------
# Processing Record for city number 399, kidal.
# ------------
# Processing Record for city number 400, ampanihy.
# ------------
# Processing Record for city number 401, great bend.
# ------------
# Processing Record for city number 402, walvis bay.
# ------------
# Processing Record for city number 403, la serena.
# ------------
# Processing Record for city number 404, samarai.
# ------------
# Processing Record for city number 405, comodoro rivadavia.
# ------------
# Processing Record for city number 406, mae sai.
# ------------
# Processing Record for city number 407, goure.
# ------------
# Processing Record for city number 408, mangan.
# ------------
# Processing Record for city number 409, sulmona.
# ------------
# Processing Record for city number 410, magdagachi.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 411, juneau.
# ------------
# Processing Record for city number 412, ewa beach.
# ------------
# Processing Record for city number 413, karak.
# ------------
# Processing Record for city number 414, pacific grove.
# ------------
# Processing Record for city number 415, srikakulam.
# ------------
# Processing Record for city number 416, pasighat.
# ------------
# Processing Record for city number 417, ponta do sol.
# ------------
# Processing Record for city number 418, kristinehamn.
# ------------
# Processing Record for city number 419, surgut.
# ------------
# Processing Record for city number 420, nyandoma.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 421, rosetta.
# ------------
# Processing Record for city number 422, moree.
# ------------
# Processing Record for city number 423, manzanillo.
# ------------
# Processing Record for city number 424, pedernales.
# ------------
# Processing Record for city number 425, kanye.
# ------------
# Processing Record for city number 426, mindelo.
# ------------
# Processing Record for city number 427, bijie.
# ------------
# Processing Record for city number 428, bintulu.
# ------------
# Processing Record for city number 429, sao joao da barra.
# ------------
# Processing Record for city number 430, vandra.
# ------------
# Processing Record for city number 431, sinegorye.
# ------------
# Processing Record for city number 432, labuhan.
# ------------
# Processing Record for city number 433, palmer.
# ------------
# Processing Record for city number 434, high level.
# ------------
# Processing Record for city number 435, deputatskiy.
# ------------
# Processing Record for city number 436, rio grande.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 437, robertsport.
# ------------
# Processing Record for city number 438, vershino-darasunskiy.
# ------------
# Processing Record for city number 439, daur.
# ------------
# Processing Record for city number 440, fort nelson.
# ------------
# Processing Record for city number 441, yatou.
# ------------
# Processing Record for city number 442, bereda.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 443, kem.
# ------------
# Processing Record for city number 444, voznesenye.
# ------------
# Processing Record for city number 445, morgan city.
# ------------
# Processing Record for city number 446, kipushi.
# ------------
# Processing Record for city number 447, yingcheng.
# ------------
# Processing Record for city number 448, ketchikan.
# ------------
# Processing Record for city number 449, nouadhibou.
# ------------
# Processing Record for city number 450, mayya.
# ------------
# Processing Record for city number 451, valley station.
# ------------
# Processing Record for city number 452, kununurra.
# ------------
# Processing Record for city number 453, kisangani.
# ------------
# Processing Record for city number 454, saint-georges.
# ------------
# Processing Record for city number 455, bahia honda.
# ------------
# Processing Record for city number 456, baykit.
# ------------
# Processing Record for city number 457, dingle.
# ------------
# Processing Record for city number 458, angoram.
# ------------
# Processing Record for city number 459, zhangye.
# ------------
# Processing Record for city number 460, algiers.
# ------------
# Processing Record for city number 461, college.
# ------------
# Processing Record for city number 462, cockburn town.
# ------------
# Processing Record for city number 463, duvan.
# ------------
# Processing Record for city number 464, bangui.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 465, madimba.
# ------------
# Processing Record for city number 466, galdar.
# ------------
# Processing Record for city number 467, fort myers beach.
# ------------
# Processing Record for city number 468, olmos.
# ------------
# Processing Record for city number 469, lensk.
# ------------
# Processing Record for city number 470, mayo.
# ------------
# Processing Record for city number 471, viedma.
# ------------
# Processing Record for city number 472, kamenka.
# ------------
# Processing Record for city number 473, klyuchi.
# ------------
# Processing Record for city number 474, kampot.
# ------------
# Processing Record for city number 475, bairiki.
# ------------
# Processing Record for city number 476, bonham.
# ------------
# Processing Record for city number 477, lufilufi.
# ------------
# Processing Record for city number 478, winkler.
# ------------
# Processing Record for city number 479, beaverlodge.
# ------------
# Processing Record for city number 480, cidreira.
# ------------
# Processing Record for city number 481, nauen.
# ------------
# Processing Record for city number 482, mbanza-ngungu.
# ------------
# Processing Record for city number 483, colares.
# ------------
# Processing Record for city number 484, port hardy.
# ------------
# Processing Record for city number 485, yumen.
# ------------
# Processing Record for city number 486, irbeyskoye.
# ------------
# Processing Record for city number 487, warri.
# ------------
# Processing Record for city number 488, ternate.
# ------------
# Processing Record for city number 489, manjacaze.
# ------------
# Processing Record for city number 490, buraydah.
# ------------
# Processing Record for city number 491, mount pleasant.
# ------------
# Processing Record for city number 492, antofagasta.
# ------------
# Processing Record for city number 493, la rioja.
# ------------
# Processing Record for city number 494, qeshm.
# ------------
# Processing Record for city number 495, rorvik.
# ------------
# Processing Record for city number 496, rincon.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 497, buala.
# ------------
# Processing Record for city number 498, saint-augustin.
# ------------
# Processing Record for city number 499, ngara.
# ------------
# Processing Record for city number 500, avera.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 501, luorong.
# ------------
# Processing Record for city number 502, san quintin.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 503, anito.
# ------------
# Processing Record for city number 504, henties bay.
# ------------
# Processing Record for city number 505, ballina.
# ------------
# Processing Record for city number 506, steinbach.
# ------------
# Processing Record for city number 507, kyabe.
# ------------
# Processing Record for city number 508, tiarei.
# ------------
# Processing Record for city number 509, dickinson.
# ------------
# Processing Record for city number 510, clinton.
# ------------
# Processing Record for city number 511, salalah.
# ------------
# Processing Record for city number 512, lazaro cardenas.
# ------------
# Processing Record for city number 513, vaitape.
# ------------
# Processing Record for city number 514, batagay.
# ------------
# Processing Record for city number 515, geraldton.
# ------------
# Processing Record for city number 516, vila velha.
# ------------
# Processing Record for city number 517, eisiskes.
# ------------
# Processing Record for city number 518, uchaly.
# ------------
# Processing Record for city number 519, delta.
# ------------
# Processing Record for city number 520, ekhabi.
# ------------
# Processing Record for city number 521, velvary.
# ------------
# Processing Record for city number 522, olafsvik.
# ------------
# Processing Record for city number 523, bloomfield.
# ------------
# Processing Record for city number 524, yangmei.
# ------------
# Processing Record for city number 525, tashtagol.
# ------------
# Processing Record for city number 526, anadyr.
# ------------
# Processing Record for city number 527, destin.
# ------------
# Processing Record for city number 528, berkak.
# ------------
# Processing Record for city number 529, ramban.
# ------------
# Processing Record for city number 530, manta.
# ------------
# Processing Record for city number 531, alaca.
# ------------
# Processing Record for city number 532, reykjavik.
# ------------
# Processing Record for city number 533, coahuayana.
# ------------
# Processing Record for city number 534, gornopravdinsk.
# ------------
# Processing Record for city number 535, lukovetskiy.
# ------------
# Processing Record for city number 536, dengfeng.
# ------------
# Processing Record for city number 537, morondava.
# ------------
# Missing field/result... skipping.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 538, sao gabriel da cachoeira.
# ------------
# Processing Record for city number 539, tsiroanomandidy.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 540, aasiaat.
# ------------
# Processing Record for city number 541, lermontovka.
# ------------
# Processing Record for city number 542, maradi.
# ------------
# Processing Record for city number 543, kiruna.
# ------------
# Processing Record for city number 544, ust-kuyga.
# ------------
# Processing Record for city number 545, salantai.
# ------------
# Processing Record for city number 546, vila.
# ------------
# Processing Record for city number 547, great falls.
# ------------
# Processing Record for city number 548, dudinka.
# ------------
# Processing Record for city number 549, hirara.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 550, kimparana.
# ------------
# Processing Record for city number 551, praya.
# ------------
# Processing Record for city number 552, ambilobe.
# ------------
# Processing Record for city number 553, baruun-urt.
# ------------
# Processing Record for city number 554, mehamn.
# ------------
# Processing Record for city number 555, megion.
# ------------
# Processing Record for city number 556, kogon.
# ------------
# Processing Record for city number 557, inhambane.
# ------------
# Processing Record for city number 558, matara.
# ------------
# Processing Record for city number 559, codajas.
# ------------
# Processing Record for city number 560, aguada de pasajeros.
# ------------
# Processing Record for city number 561, kholtoson.
# ------------
# Missing field/result... skipping.
# ------------
# Processing Record for city number 562, necochea.
# ------------
# Processing Record for city number 563, lucea.
# ------------
# Processing Record for city number 564, non sang.
# ------------
# Processing Record for city number 565, komsomolets.
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Build and display the dataFrame
weather_dict = {
    "City": cityname,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date" : date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng":lng,
    "Max Temp":max_temp,
    "Wind Speed":windspeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Lat           565
# Lng           565
# Max Temp      565
# Wind Speed    565
# dtype: int64

# %%
weather_data
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Leningradskiy         100      RU  1586969215        95  69.38  178.42
# 1           Vanimo          32      PG  1586969537        79  -2.67  141.30
# 2            Erzin          75      TR  1586969537        63  36.96   36.20
# 3          Radomir          40      BG  1586969443        56  42.54   22.96
# 4    Mar del Plata          40      AR  1586969194        55 -38.00  -57.56
# ..             ...         ...     ...         ...       ...    ...     ...
# 560      Kholtoson           3      RU  1586969612        57  50.30  103.31
# 561       Necochea           0      AR  1586969612        67 -38.55  -58.74
# 562          Lucea          20      JM  1586969613        70  18.45  -78.17
# 563       Non Sang          89      TH  1586969613        65  16.87  102.57
# 564    Komsomolets          50      KZ  1586969613        64  53.75   62.07
#
#      Max Temp  Wind Speed
# 0       14.00        4.38
# 1       80.19        3.44
# 2       66.20        9.17
# 3       48.99        8.05
# 4       64.00       16.11
# ..        ...         ...
# 560     29.97        0.89
# 561     66.99       11.01
# 562     84.20       10.29
# 563     93.99        2.24
# 564     46.00       11.56
#
# [565 rows x 9 columns]

# %%
#Export the Dataframe to a csv file located in output_data folder
weather_data.to_csv("../output_data/cities.csv", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for Max temperature vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Max Temp']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(F)')
plt.title('City Latitude vs Max Temperature 04/15/2020')
plt.savefig("../output_data/fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a Scatter Plot for Humidity vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Humidity']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs Humidity 04/15/2020')
plt.savefig("../output_data/fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a Scatter Plot for Clodiness vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Cloudiness']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs Cloudiness 04/15/2020')
plt.savefig("../output_data/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a Scatter Plot for Wind Speed vs latitude
x_values = weather_data['Lat']
y_values = weather_data['Wind Speed']
edgecolor=['black']
colors=['lightblue']
plt.grid(color='grey', linestyle='-',linewidth=0.55,alpha=0.75)
plt.scatter(x_values,y_values,edgecolors=edgecolor, color=colors)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.title('City Latitude vs Wind Speed 04/15/2020')
plt.savefig("../output_data/fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northerncities=weather_data.loc[weather_data["Lat"]>=0.0]
southerncities=weather_data.loc[weather_data["Lat"]<0.0]
northerncities.reset_index(inplace=True)
southerncities.reset_index(inplace=True)
southerncities.head()
# Out:
#    index           City  Cloudiness Country        Date  Humidity    Lat  \
# 0      1         Vanimo          32      PG  1586969537        79  -2.67
# 1      4  Mar del Plata          40      AR  1586969194        55 -38.00
# 2      8       Lorengau          99      PG  1586969247        75  -2.02
# 3      9   Port Lincoln          45      AU  1586969213        81 -34.73
# 4     11      Busselton          34      AU  1586969196        59 -33.65
#
#       Lng  Max Temp  Wind Speed
# 0  141.30     80.19        3.44
# 1  -57.56     64.00       16.11
# 2  147.27     81.77        2.21
# 3  135.87     62.82       14.14
# 4  115.33     55.00        5.41

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linearreg(x_val, y_val, x_label, y_label,posn, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
    regress_values = x_val * slope + intercept
    print(f"The r-squared is: {rvalue**2}")
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_val,y_val)
    plt.plot(x_val,regress_values,"r-")
    plt.annotate(line_eq,posn,fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Max Temp vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Max Temp"]
x_label= "Lat"
y_label= "Max Temp"
posn=(6,10)
title="Northern Hemisphere Max Temp vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label, posn,title)
plt.savefig("../output_data/fig5.png")
# Out:
# The r-squared is: 0.7684840653623436

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Max Temp vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Max Temp"]
x_label= "Lat"
y_label= "Max Temp"
posn=(-30,55)
title="Southern Hemisphere Max Temp vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig6.png")
# Out:
# The r-squared is: 0.5586569707300805

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Humidity vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Humidity"]
x_label= "Lat"
y_label= "Humidity (%)"
posn=(45,12)
title="Northern Hemisphere Humidity vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig7.png")
# Out:
# The r-squared is: 0.08460822630773639

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Humidity vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Humidity"]
x_label= "Lat"
y_label= "Humidity (%)"
posn=(-22,20)
title="Southern Hemisphere Humidity vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig8.png")
# Out:
# The r-squared is: 0.003402614785773365

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Cloudiness vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Cloudiness"]
x_label= "Lat"
y_label= "Cloudiness (%)"
posn=(34,30)
title="Northern Hemisphere Cloudiness vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig9.png")
# Out:
# The r-squared is: 0.04137135333222115

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Cloudiness vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Cloudiness"]
x_label= "Lat"
y_label= "Cloudiness (%)"
posn=(-22,10)
title="Southern Hemisphere Cloudiness vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig10.png")
# Out:
# The r-squared is: 0.031888484104352306

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Wind Speed vs latitude for cities in Northern Hemisphere
x_val= northerncities["Lat"]
y_val= northerncities["Wind Speed"]
x_label= "Lat"
y_label= "Wind Speed (mph)"
posn=(1,28)
title="Northern Hemisphere Wind Speed vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig11.png")
# Out:
# The r-squared is: 0.022988031295229593

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for Wind Speed vs latitude for cities in Southern Hemisphere
x_val= southerncities["Lat"]
y_val= southerncities["Wind Speed"]
x_label= "Lat"
y_label= "Wind Speed (mph)"
posn=(-22,30)
title="Southern Hemisphere Wind Speed vs Lat 04/15/2020"
linearreg(x_val, y_val, x_label, y_label,posn, title)
plt.savefig("../output_data/fig12.png")
# Out:
# The r-squared is: 0.035389005644668174
