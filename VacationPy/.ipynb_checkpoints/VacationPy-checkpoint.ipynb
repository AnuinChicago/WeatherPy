# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\aguha\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\aguha\anaconda3\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\aguha\anaconda3\lib\site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: six in c:\users\aguha\anaconda3\lib\site-packages (from gmaps) (1.12.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\aguha\anaconda3\lib\site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\aguha\anaconda3\lib\site-packages (from gmaps) (7.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aguha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\aguha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\aguha\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: decorator in c:\users\aguha\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (4.4.0)
# Requirement already satisfied: ipython-genutils in c:\users\aguha\anaconda3\lib\site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (41.4.0)
# Requirement already satisfied: pickleshare in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pygments in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (2.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.1)
# Requirement already satisfied: jedi>=0.10 in c:\users\aguha\anaconda3\lib\site-packages (from ipython>=5.3.0->gmaps) (0.15.1)
# Requirement already satisfied: tornado>=4.2 in c:\users\aguha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-client in c:\users\aguha\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\aguha\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\aguha\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.0.2)
# Requirement already satisfied: jupyter-core in c:\users\aguha\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.5.0)
# Requirement already satisfied: wcwidth in c:\users\aguha\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.7)
# Requirement already satisfied: parso>=0.5.0 in c:\users\aguha\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\aguha\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\aguha\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (18.1.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\aguha\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (223)
# Requirement already satisfied: Send2Trash in c:\users\aguha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: jinja2 in c:\users\aguha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.10.3)
# Requirement already satisfied: nbconvert in c:\users\aguha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\aguha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.2)
# Requirement already satisfied: prometheus-client in c:\users\aguha\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\aguha\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\aguha\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\aguha\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: bleach in c:\users\aguha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\aguha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aguha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\aguha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: defusedxml in c:\users\aguha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: testpath in c:\users\aguha\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.2)
# Requirement already satisfied: webencodings in c:\users\aguha\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
# Import API key
from api_keys import g_key
# Import API key
from api_keys import weather_api_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_pd = pd.read_csv("../output_data/cities.csv")
cities_pd.rename(columns={'years':'Lat'})
cities_pd.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Vaini          20      TO  1586731535        69 -21.20 -175.20
# 1     Khatanga          48      RU  1586731535        95  71.97  102.50
# 2  Port Alfred          12      ZA  1586731535        82 -33.59   26.89
# 3       Albany          75      US  1586731236        25  42.60  -73.97
# 4   Talcahuano           3      CL  1586731536        48 -36.72  -73.12
#
#    Max Temp  Wind Speed
# 0     80.60        9.17
# 1      6.64        9.89
# 2     60.01        3.00
# 3     62.60       16.11
# 4     60.80       11.41

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# Store latitude and longitude in locations
locations = cities_pd[["Lat", "Lng"]].astype(float)

# Store Humidity values in Humidity
humidity = cities_pd["Humidity"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Ideal weather conditions for me is when, temp is between 85F and 70F, not too humid, cloudy and windy
ideal_weather_df=cities_pd
ideal_weather_df = ideal_weather_df.loc[(ideal_weather_df["Max Temp"]<85)  & (ideal_weather_df["Max Temp"]>70)]
ideal_weather_df =ideal_weather_df.loc[(ideal_weather_df)["Humidity"]<40 ]
ideal_weather_df =ideal_weather_df.loc[(ideal_weather_df)["Wind Speed"]<20 ]
ideal_weather_df =ideal_weather_df.loc[(ideal_weather_df)["Cloudiness"]<25 ]
ideal_weather_df=ideal_weather_df.dropna()
ideal_weather_df
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 48       Bilma           0      NE  1586731543        15  18.69   12.92
# 189       Tonk          12      IN  1586731563        29  26.17   75.78
# 226  Mount Isa          23      AU  1586731568        35 -20.73  139.50
# 388    Pahrump          20      US  1586731591        21  36.21 -115.98
# 474    Emerald          10      AU  1586731603        35 -23.53  148.17
# 507   Dātāganj           2      IN  1586731608        25  28.03   79.40
#
#      Max Temp  Wind Speed
# 48      80.22        7.45
# 189     79.99        2.13
# 226     73.40       12.35
# 388     75.00        5.82
# 474     71.01       10.29
# 507     78.66        4.90

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df=ideal_weather_df
hotel_df["Hotel Name"]= ""
#base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
}
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
#     print the name_address url, avoid doing for public github repos in order to avoid exposing key
#     print(name_address.url)

    # convert to json
    name_address = name_address.json()
    print(index)
    #print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# 48
# 189
# 226
# 388
# 474
# 507

# %%
hotel_df
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 48       Bilma           0      NE  1586731543        15  18.69   12.92
# 189       Tonk          12      IN  1586731563        29  26.17   75.78
# 226  Mount Isa          23      AU  1586731568        35 -20.73  139.50
# 388    Pahrump          20      US  1586731591        21  36.21 -115.98
# 474    Emerald          10      AU  1586731603        35 -23.53  148.17
# 507   Dātāganj           2      IN  1586731608        25  28.03   79.40
#
#      Max Temp  Wind Speed                  Hotel Name
# 48      80.22        7.45  Expeditions Ténére voyages
# 189     79.99        2.13               Hotel Sheetal
# 226     73.40       12.35   ibis Styles Mt Isa Verona
# 388     75.00        5.82  Best Western Pahrump Oasis
# 474     71.01       10.29           The Irish Village
# 507     78.66        4.90                Hani Traders

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

markers = gmaps.marker_layer(locations,info_box_content =hotel_info)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
